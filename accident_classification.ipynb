# %% [markdown]
# <a href="https://colab.research.google.com/github/vijayganeshn96/Real-Time-Crash-Detection-and-Response-System-Using-Django-and-Computer-Vision-/blob/main/accident_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers
from time import perf_counter
import os
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from tensorflow.keras.utils import plot_model

# %%
from google.colab import drive
drive.mount('/content/data')
# Out:
# Mounted at /content/drive

# %%
## Defining batch specfications
batch_size = 100
img_height = 250
img_width = 250

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

print(os.path.exists('data/train'))  # Should return True if the directory exists
print(os.listdir('data'))  # Check if 'train' is inside 'data'
# Out:
# False
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-acbe9c663ccf> in <cell line: 0>()
#       2
#       3 print(os.path.exists('/content/drive/MyDrive/data/train'))  # Should return True if the directory exists
# ----> 4 print(os.listdir('data'))  # Check if 'train' is inside 'data'
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data'

# %%
## loading training set
training_data = tf.keras.preprocessing.image_dataset_from_directory('data/train',seed=42,image_size= (img_height, img_width),batch_size=batch_size,color_mode='rgb')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b6351421d201> in <cell line: 0>()
#       1 ## loading training set
# ----> 2 training_data = tf.keras.preprocessing.image_dataset_from_directory('data/train',seed=42,image_size= (img_height, img_width),batch_size=batch_size,color_mode='rgb')
#
# NameError: name 'tf' is not defined

# %%
from google.colab import drive
# drive.mount('/content/drive')
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
## loading validation dataset
validation_data =  tf.keras.preprocessing.image_dataset_from_directory(
    'data/val',
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 98 files belonging to 2 classes.

# %%
## loading testing dataset
testing_data = tf.keras.preprocessing.image_dataset_from_directory(
    'data/test',
    seed=42,
    image_size= (img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb'
)
# Out:
# Found 100 files belonging to 2 classes.

# %%
testing_data
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 250, 250, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
class_names = training_data.class_names
class_names
# Out:
# ['Accident', 'Non Accident']

# %%
## Configuring dataset for performance
AUTOTUNE = tf.data.experimental.AUTOTUNE
training_data = training_data.cache().prefetch(buffer_size=AUTOTUNE)
testing_data = testing_data.cache().prefetch(buffer_size=AUTOTUNE)

# %%
## Defining Cnn
model = tf.keras.models.Sequential([
  layers.BatchNormalization(),
  layers.Conv2D(32, 3, activation='relu'), # Conv2D(f_size, filter_size, activation) # relu, sigmoid, softmax
  layers.MaxPooling2D(), # MaxPooling
  layers.Conv2D(64, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(256, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(512, activation='relu'),
  layers.Dense(len(class_names), activation= 'softmax')
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.build((None, 250, 250, 3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (Batch  (None, 250, 250, 3)       12
#  Normalization)
#
#  conv2d (Conv2D)             (None, 248, 248, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 124, 124, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 122, 122, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 61, 61, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 59, 59, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 29, 29, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 27, 27, 256)       295168
#
#  max_pooling2d_3 (MaxPoolin  (None, 13, 13, 256)       0
#  g2D)
#
#  flatten (Flatten)           (None, 43264)             0
#
#  dense (Dense)               (None, 512)               22151680
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 22541134 (85.99 MB)
# Trainable params: 22541128 (85.99 MB)
# Non-trainable params: 6 (24.00 Byte)
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
## lets train our CNN
checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
history = model.fit(training_data, validation_data=validation_data, epochs = 20, callbacks=callbacks_list)
# Out:
# Epoch 1/20
# 8/8 [==============================] - ETA: 0s - loss: 2.3556 - accuracy: 0.5348
# Epoch 1: val_accuracy improved from -inf to 0.59184, saving model to model_weights.h5
# C:\Users\TPS PROJECTS\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 8/8 [==============================] - 221s 26s/step - loss: 2.3556 - accuracy: 0.5348 - val_loss: 0.6727 - val_accuracy: 0.5918
# Epoch 2/20
# 8/8 [==============================] - ETA: 0s - loss: 0.6915 - accuracy: 0.6233
# Epoch 2: val_accuracy did not improve from 0.59184
# 8/8 [==============================] - 194s 24s/step - loss: 0.6915 - accuracy: 0.6233 - val_loss: 0.7404 - val_accuracy: 0.4796
# Epoch 3/20
# 8/8 [==============================] - ETA: 0s - loss: 0.6486 - accuracy: 0.6220
# Epoch 3: val_accuracy improved from 0.59184 to 0.62245, saving model to model_weights.h5
# 8/8 [==============================] - 196s 25s/step - loss: 0.6486 - accuracy: 0.6220 - val_loss: 0.6242 - val_accuracy: 0.6224
# Epoch 4/20
# 8/8 [==============================] - ETA: 0s - loss: 0.6127 - accuracy: 0.6448
# Epoch 4: val_accuracy did not improve from 0.62245
# 8/8 [==============================] - 190s 24s/step - loss: 0.6127 - accuracy: 0.6448 - val_loss: 0.6812 - val_accuracy: 0.6020
# Epoch 5/20
# 8/8 [==============================] - ETA: 0s - loss: 0.5860 - accuracy: 0.6903
# Epoch 5: val_accuracy improved from 0.62245 to 0.64286, saving model to model_weights.h5
# 8/8 [==============================] - 195s 24s/step - loss: 0.5860 - accuracy: 0.6903 - val_loss: 0.6515 - val_accuracy: 0.6429
# Epoch 6/20
# 8/8 [==============================] - ETA: 0s - loss: 0.5362 - accuracy: 0.7370
# Epoch 6: val_accuracy did not improve from 0.64286
# 8/8 [==============================] - 192s 24s/step - loss: 0.5362 - accuracy: 0.7370 - val_loss: 0.6493 - val_accuracy: 0.6122
# Epoch 7/20
# 8/8 [==============================] - ETA: 0s - loss: 0.5016 - accuracy: 0.7421
# Epoch 7: val_accuracy improved from 0.64286 to 0.68367, saving model to model_weights.h5
# 8/8 [==============================] - 194s 24s/step - loss: 0.5016 - accuracy: 0.7421 - val_loss: 0.5445 - val_accuracy: 0.6837
# Epoch 8/20
# 8/8 [==============================] - ETA: 0s - loss: 0.4536 - accuracy: 0.7762
# Epoch 8: val_accuracy improved from 0.68367 to 0.75510, saving model to model_weights.h5
# 8/8 [==============================] - 204s 26s/step - loss: 0.4536 - accuracy: 0.7762 - val_loss: 0.4980 - val_accuracy: 0.7551
# Epoch 9/20
# 8/8 [==============================] - ETA: 0s - loss: 0.3626 - accuracy: 0.8382
# Epoch 9: val_accuracy did not improve from 0.75510
# 8/8 [==============================] - 254s 32s/step - loss: 0.3626 - accuracy: 0.8382 - val_loss: 0.6234 - val_accuracy: 0.7347
# Epoch 10/20
# 8/8 [==============================] - ETA: 0s - loss: 0.2470 - accuracy: 0.9039
# Epoch 10: val_accuracy did not improve from 0.75510
# 8/8 [==============================] - 317s 40s/step - loss: 0.2470 - accuracy: 0.9039 - val_loss: 0.8722 - val_accuracy: 0.7245
# Epoch 11/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1930 - accuracy: 0.9204
# Epoch 11: val_accuracy improved from 0.75510 to 0.77551, saving model to model_weights.h5
# 8/8 [==============================] - 318s 41s/step - loss: 0.1930 - accuracy: 0.9204 - val_loss: 1.0229 - val_accuracy: 0.7755
# Epoch 12/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.9254
# Epoch 12: val_accuracy improved from 0.77551 to 0.82653, saving model to model_weights.h5
# 8/8 [==============================] - 334s 42s/step - loss: 0.1820 - accuracy: 0.9254 - val_loss: 0.3448 - val_accuracy: 0.8265
# Epoch 13/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1069 - accuracy: 0.9646
# Epoch 13: val_accuracy improved from 0.82653 to 0.83673, saving model to model_weights.h5
# 8/8 [==============================] - 334s 42s/step - loss: 0.1069 - accuracy: 0.9646 - val_loss: 0.5275 - val_accuracy: 0.8367
# Epoch 14/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1028 - accuracy: 0.9583
# Epoch 14: val_accuracy did not improve from 0.83673
# 8/8 [==============================] - 265s 32s/step - loss: 0.1028 - accuracy: 0.9583 - val_loss: 0.6235 - val_accuracy: 0.8265
# Epoch 15/20
# 8/8 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9646
# Epoch 15: val_accuracy improved from 0.83673 to 0.88776, saving model to model_weights.h5
# 8/8 [==============================] - 238s 31s/step - loss: 0.0909 - accuracy: 0.9646 - val_loss: 0.4407 - val_accuracy: 0.8878
# Epoch 16/20
# 8/8 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 0.9646
# Epoch 16: val_accuracy did not improve from 0.88776
# 8/8 [==============================] - 329s 41s/step - loss: 0.0914 - accuracy: 0.9646 - val_loss: 0.6503 - val_accuracy: 0.7959
# Epoch 17/20
# 8/8 [==============================] - ETA: 0s - loss: 0.0992 - accuracy: 0.9633
# Epoch 17: val_accuracy did not improve from 0.88776
# 8/8 [==============================] - 327s 41s/step - loss: 0.0992 - accuracy: 0.9633 - val_loss: 0.8447 - val_accuracy: 0.7959
# Epoch 18/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1392 - accuracy: 0.9532
# Epoch 18: val_accuracy did not improve from 0.88776
# 8/8 [==============================] - 253s 31s/step - loss: 0.1392 - accuracy: 0.9532 - val_loss: 0.3259 - val_accuracy: 0.8878
# Epoch 19/20
# 8/8 [==============================] - ETA: 0s - loss: 0.0862 - accuracy: 0.9722
# Epoch 19: val_accuracy improved from 0.88776 to 0.89796, saving model to model_weights.h5
# 8/8 [==============================] - 318s 40s/step - loss: 0.0862 - accuracy: 0.9722 - val_loss: 0.3265 - val_accuracy: 0.8980
# Epoch 20/20
# 8/8 [==============================] - ETA: 0s - loss: 0.0707 - accuracy: 0.9735
# Epoch 20: val_accuracy did not improve from 0.89796
# 8/8 [==============================] - 199s 24s/step - loss: 0.0707 - accuracy: 0.9735 - val_loss: 0.3049 - val_accuracy: 0.8878

# %%
###### serialize model structure to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# %%
## stats on training data
plt.plot(history.history['loss'], label = 'training loss')
plt.plot(history.history['accuracy'], label = 'training accuracy')
plt.grid(True)
plt.legend()

# %%
## stats on training data
plt.plot(history.history['val_loss'], label = 'validation loss')
plt.plot(history.history['val_accuracy'], label = 'validation accuracy')
plt.grid(True)
plt.legend()

# %%
## lets vizualize results on testing data
AccuracyVector = []
plt.figure(figsize=(30, 30))
for images, labels in testing_data.take(1):
    predictions = model.predict(images)
    predlabel = []
    prdlbl = []

    for mem in predictions:
        predlabel.append(class_names[np.argmax(mem)])
        prdlbl.append(np.argmax(mem))

    AccuracyVector = np.array(prdlbl) == labels
    for i in range(40):
        ax = plt.subplot(10, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title('Pred: '+ predlabel[i]+' actl:'+class_names[labels[i]] )
        plt.axis('off')
        plt.grid(True)
# Out:
# 4/4 [==============================] - 6s 1s/step
